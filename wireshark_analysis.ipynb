# %% [markdown]
# # Wireshark Analysis

# %%
import pandas as pd
from data.wireshark_analysis_data import data_analysis

# %% [markdown]
# ## Retrieve the Data
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv('wireshark_cap.csv')
data.head()
# Out:
#    No.      Time         Source    Destination Protocol  Length  \
# 0    1  0.000000  192.168.86.39  17.248.228.70  TLSv1.2     635
# 1    2  0.000279  192.168.86.39  17.248.228.70  TLSv1.2     165
# 2    3  0.017569  17.248.228.70  192.168.86.39      TCP      66
# 3    4  0.017570  17.248.228.70  192.168.86.39      TCP    1514
# 4    5  0.017644  192.168.86.39  17.248.228.70      TCP      66
#
#                                                 Info
# 0                                   Application Data
# 1                                   Application Data
# 2  443  >  58736 [ACK] Seq=1 Ack=669 Win=63 Len=0...
# 3  443  >  58736 [ACK] Seq=1 Ack=669 Win=63 Len=1...
# 4  58736  >  443 [ACK] Seq=669 Ack=1449 Win=2025 ...

# %%
data_analysis(data)
# Out:
# <h1 style='text-align:center; font-weight:bold;'>Data Preprocessing</h1>
# <ul><li>There are missing values in the dataset</li></ul>
# <ul><li>The total number of rows with missing values is 13</li></ul>
# <ul><li>The dataset has 358320 rows and 7 columns after deleting rows with missing values</li></ul>
# <h1 style='text-align:center; font-weight:bold;'>Source Analysis</h1>
# <h2 style='text-align:center; font-weight:bold;'>Source Analysis for All Addresses</h2>
# <h2 style='text-align:center; font-weight:bold;'>Source Analysis for Private Addresses</h2>
# <h2 style='text-align:center; font-weight:bold;'>Source Analysis for Public Addresses</h2>
# <h2 style='text-align:center; font-weight:bold;'>Source Analysis for IPv6 Addresses</h2>
# <h1 style='text-align:center; font-weight:bold;'>Destination Analysis</h1>
# <h2 style='text-align:center; font-weight:bold;'>Destination Analysis for All Addresses</h2>
# ...
